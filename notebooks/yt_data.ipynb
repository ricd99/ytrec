# %% [markdown]
# ## Setup

# %%
from googleapiclient.discovery import build
import json
import re
from collections import Counter
from datetime import datetime
from googleapiclient.discovery import build
import pandas as pd
import numpy as np

# %%
with open ("../performative.txt", "r") as f:
    lines = f.readlines()
    API_KEY = lines[2].strip()
    
yt = build("youtube", "v3", developerKey=API_KEY)

# %% [markdown]
# ## Initial testing

# %%
# request = yt.search().list(
#     part = "snippet",
#     q = "Mr. Beast", 
#     type = "channel", 
#     maxResults = 5  
# )
# response = request.execute()

# %%
# print(json.dumps(response, indent=2))
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "MupnNRGJH1KG6Is26QmJQbffWBY",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "CA",
#   "pageInfo": {
#     "totalResults": 43774,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "9VY0mroPCq4siyhZXwnBETMaJ7w",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UCX6OQ3DkcsbYNE6H8uQQuVA"
#       },
#       "snippet": {
#         "publishedAt": "2012-02-20T00:43:50Z",
#         "channelId": "UCX6OQ3DkcsbYNE6H8uQQuVA",
#         "title": "MrBeast",
#         "description": "SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast Gaming video every single Saturday at noon eastern time!",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/nxYrc_1_2f77DoBadyxMTmv7ZpRZapHR5jbuYe7PlPd5cIRJxtNNEYyOC0ZsxaDyJJzXrnJiuDE=s88-c-k-c0xffffffff-no-rj-mo"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/nxYrc_1_2f77DoBadyxMTmv7ZpRZapHR5jbuYe7PlPd5cIRJxtNNEYyOC0ZsxaDyJJzXrnJiuDE=s240-c-k-c0xffffffff-no-rj-mo"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/nxYrc_1_2f77DoBadyxMTmv7ZpRZapHR5jbuYe7PlPd5cIRJxtNNEYyOC0ZsxaDyJJzXrnJiuDE=s800-c-k-c0xffffffff-no-rj-mo"
#           }
#         },
#         "channelTitle": "MrBeast",
#         "liveBroadcastContent": "none",
#         "publishTime": "2012-02-20T00:43:50Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "qCS1RRp7en6WQ3OGKi1JNYGojGM",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UCIPPMRA040LQr5QPyJEbmXA"
#       },
#       "snippet": {
#         "publishedAt": "2020-04-07T18:46:13Z",
#         "channelId": "UCIPPMRA040LQr5QPyJEbmXA",
#         "title": "MrBeast Gaming",
#         "description": "New MrBeast or MrBeast Gaming video every single Saturday at noon eastern time! MrBeast Gaming - SUBSCRIBE OR ELSE.",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_lMiSL6eHqg2dVxvll6mVMeXo1qVak4TZ4_7mEWdobRRCk=s88-c-k-c0xffffffff-no-rj-mo"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_lMiSL6eHqg2dVxvll6mVMeXo1qVak4TZ4_7mEWdobRRCk=s240-c-k-c0xffffffff-no-rj-mo"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/ytc/AIdro_lMiSL6eHqg2dVxvll6mVMeXo1qVak4TZ4_7mEWdobRRCk=s800-c-k-c0xffffffff-no-rj-mo"
#           }
#         },
#         "channelTitle": "MrBeast Gaming",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-04-07T18:46:13Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "J8gFXFiVF9kcZOKPBcaCmFaQDbk",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UCAiLfjNXkNv24uhpzUgPa6A"
#       },
#       "snippet": {
#         "publishedAt": "2020-09-18T02:17:59Z",
#         "channelId": "UCAiLfjNXkNv24uhpzUgPa6A",
#         "title": "Beast Philanthropy",
#         "description": "100% of the profits from my ad revenue, merch sales, and sponsorships will go towards making the world a better place!",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/GskFAiD8zDR_8ac8qF4DjPwAl4RBwFZEU4EOrX_iK9_YpocbmrAKXF7AlKGmgoJ_3u62YDVkbDc=s88-c-k-c0xffffffff-no-rj-mo"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/GskFAiD8zDR_8ac8qF4DjPwAl4RBwFZEU4EOrX_iK9_YpocbmrAKXF7AlKGmgoJ_3u62YDVkbDc=s240-c-k-c0xffffffff-no-rj-mo"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/GskFAiD8zDR_8ac8qF4DjPwAl4RBwFZEU4EOrX_iK9_YpocbmrAKXF7AlKGmgoJ_3u62YDVkbDc=s800-c-k-c0xffffffff-no-rj-mo"
#           }
#         },
#         "channelTitle": "Beast Philanthropy",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-09-18T02:17:59Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "gYyS4ZE_cRpcyeIhbHUPYa0puro",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UC4-79UOlP48-QNGgCko5p2g"
#       },
#       "snippet": {
#         "publishedAt": "2020-08-21T19:46:50Z",
#         "channelId": "UC4-79UOlP48-QNGgCko5p2g",
#         "title": "MrBeast 2",
#         "description": "my second channel for other videos and shorts :) subscribe.",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/Jd7IA_TOGrW-oXKgX-m5CBJB0tqMemQ-zhZZYmCJxF4w06dcNREG89dHbR_GGLra1TzSJqoKjFM=s88-c-k-c0xffffffff-no-rj-mo"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/Jd7IA_TOGrW-oXKgX-m5CBJB0tqMemQ-zhZZYmCJxF4w06dcNREG89dHbR_GGLra1TzSJqoKjFM=s240-c-k-c0xffffffff-no-rj-mo"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/Jd7IA_TOGrW-oXKgX-m5CBJB0tqMemQ-zhZZYmCJxF4w06dcNREG89dHbR_GGLra1TzSJqoKjFM=s800-c-k-c0xffffffff-no-rj-mo"
#           }
#         },
#         "channelTitle": "MrBeast 2",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-08-21T19:46:50Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "DMW8W0RRg9iuziGxjJ60D688CDQ",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UCluBATXIP9doWvougjUVUGQ"
#       },
#       "snippet": {
#         "publishedAt": "2021-08-05T17:54:49Z",
#         "channelId": "UCluBATXIP9doWvougjUVUGQ",
#         "title": "MrBeast \u041d\u0430 \u0420\u0443\u0441\u0441\u043a\u043e\u043c",
#         "description": "\u0414\u043e\u0441\u0442\u0438\u0436\u0435\u043d\u0438\u044f - \u0421\u043e\u0431\u0440\u0430\u043d\u043e $20 000 000 \u043d\u0430 \u043f\u043e\u0441\u0430\u0434\u043a\u0443 20 000 000 \u0434\u0435\u0440\u0435\u0432\u044c\u0435\u0432. - \u041e\u0442\u0434\u0430\u043d\u044b \u043c\u0438\u043b\u043b\u0438\u043e\u043d\u044b \u043d\u0430 \u0431\u043b\u0430\u0433\u043e\u0442\u0432\u043e\u0440\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0441\u0442\u044c ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/FI3Ck9gGxyoI9Ukj96GdJVTY6ipfP7LjQnV_gJIvUS-EfSlR8H3TqeN6R8yNf10s1LYunisu3g=s88-c-k-c0xffffffff-no-rj-mo"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/FI3Ck9gGxyoI9Ukj96GdJVTY6ipfP7LjQnV_gJIvUS-EfSlR8H3TqeN6R8yNf10s1LYunisu3g=s240-c-k-c0xffffffff-no-rj-mo"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/FI3Ck9gGxyoI9Ukj96GdJVTY6ipfP7LjQnV_gJIvUS-EfSlR8H3TqeN6R8yNf10s1LYunisu3g=s800-c-k-c0xffffffff-no-rj-mo"
#           }
#         },
#         "channelTitle": "MrBeast \u041d\u0430 \u0420\u0443\u0441\u0441\u043a\u043e\u043c",
#         "liveBroadcastContent": "none",
#         "publishTime": "2021-08-05T17:54:49Z"
#       }
#     }
#   ]
# }

# %%
# def get_channel_data(channei_id):
#     response = yt.channels().list()

# %% [markdown]
# ## Getting data from api

# %% [markdown]
# ### Helpers

# %%
GENRE_MAP = {
    "1":  "Film & Animation",
    "2":  "Autos & Vehicles",
    "10": "Music",
    "15": "Pets & Animals",
    "17": "Sports",
    "19": "Travel & Events",
    "20": "Gaming",
    "22": "People & Blogs",
    "23": "Comedy",
    "24": "Entertainment",
    "25": "News & Politics",
    "26": "Howto & Style",
    "27": "Education",
    "28": "Science & Technology",
    "29": "Nonprofits & Activism",
}

# %%
### REQUIRES: ascending sorted list of datetime objects
def calculate_upload_gap(dates):
    if len(dates) < 2:
        return None
    gaps = [(dates[i+1] - dates[i]).total_seconds() for i in range(len(dates) - 1)]
    avg_secs_between_uploads = round(sum(gaps) / len(gaps), 2)
    return avg_secs_between_uploads

# %%
improper_duration_counter = 0 #TODO: hacky global variable, replace with logging

# %%
def to_seconds(duration):
    if not duration:
        improper_duration_counter += 1
        print("missing duration")
        return 0 #TODO: reduces accuracy
    match = re.match(r"PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?", duration)
    if not match:
        improper_duration_counter += 1
        print("duration format doesn't match")
        return 0 #TODO: reduces accuracy
    return int(match.group(1) or 0) * 3600 + int(match.group(2) or 0) * 60 + int(match.group(3) or 0)

# %% [markdown]
# ### data sourcing functions

# %%
def get_profile(channel_id):
    response = yt.channels().list(
        part="snippet,contentDetails,topicDetails,brandingSettings", #TODO: never used brandingSettings
        id=channel_id
    ).execute()

    item = response["items"][0]
    snippet = item["snippet"]
    uploads_id = item["contentDetails"]["relatedPlaylists"]["uploads"]
    raw_categories = item.get("topicDetails", {}).get("topicCategories", [])
    categories = [url.split("/")[-1].replace("_", " ") for url in raw_categories]

    return snippet, uploads_id, categories

# %%
def get_recent_videos_and_dates(uploads_id):
    response = yt.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=uploads_id,
        maxResults=10
    ).execute()

    videos=[
        {
            "video_id": item["contentDetails"]["videoId"],
            "published_at": item["snippet"]["publishedAt"],
        }
        for item in response["items"]
    ]

    upload_dates = sorted([datetime.fromisoformat(v["published_at"].replace("Z", "+00:00")) for v in videos])
    video_ids = [v["video_id"] for v in videos]
    return video_ids, upload_dates

# %%
def get_videos_data(video_ids):
    response = yt.videos().list(
        part="snippet,contentDetails",
        id=",".join(video_ids)
    ).execute()

    tags, genres, durations, titles = [], [], [], []

    for v in response["items"]:
        tags.extend(v["snippet"].get("tags", []))
        genres.append(GENRE_MAP.get(v["snippet"].get("categoryId"), "Unknown"))
        durations.append(to_seconds(v["contentDetails"].get("duration")))
        titles.append(v["snippet"].get("title"))
    
    return tags, genres, durations, titles

# %%
def main(channel_id):
    snippet, uploads_id, categories = get_profile(channel_id)
    video_ids, upload_dates = get_recent_videos_and_dates(uploads_id)
    avg_upload_gap = calculate_upload_gap(upload_dates)
    tags, genres, durations, titles = get_videos_data(video_ids)

    return {
        "channel_id": channel_id,
        "channel_name": snippet.get("title"),
        "description": snippet.get("description"),
        "country": snippet.get("country"),
        "defaultLanguage": snippet.get("defaultLanguage"),
        "created_date": snippet.get("publishedAt"),
        "category": categories,
        "aggregated_tags": list(set(tags)),
        "most_common_video_genre": Counter(genres).most_common(1)[0][0] if genres else None,
        "all_video_genres": list(set(genres)),
        "avg_duration_seconds": round(sum(durations) / len(durations), 2) if durations else None,
        "avg_seconds_between_uploads": avg_upload_gap,
        "recent_video_titles": titles,
    }

# %% [markdown]
# ## Script for dataset

# %% [markdown]
# columns for dataset:
# - from given dataset
#     - channel_id
#     - channel_name
#     - description
#     - country
#     - defaultLanguage
#     - created_date
#     - category
# - from yt api
#     - aggregated_tags
#     - most_common_video_genre
#     - all_video_genres
#     - avg_duration_seconds
#     - avg_seconds_between_uploads
#     - recent_video_titles

# %%
df = pd.read_csv("../data/raw/youtube_channel_info_v2.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15830 entries, 0 to 15829
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   channel_name         15830 non-null  object
#  1   channel_id           15830 non-null  object
#  2   view_count           15830 non-null  int64
#  3   category             15722 non-null  object
#  4   country              14030 non-null  object
#  5   defaultLanguage      1725 non-null   object
#  6   subscriber_count     15830 non-null  int64
#  7   created_date         15830 non-null  object
#  8   description          14929 non-null  object
#  9   custom_url           15808 non-null  object
#  10  thumbnail            15830 non-null  object
#  11  video_count          15830 non-null  int64
#  12  videos_last_30_days  15830 non-null  int64
#  13  views_last_30_days   15830 non-null  int64
#  14  uploads_playlist_id  15830 non-null  object
#  15  last_10_video_ids    15774 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 1.9+ MB

# %%
df.head() #TODO: consider removing music channels?
# Out:
#     channel_name                channel_id   view_count  \
# 0      BLACKPINK  UCOmHUn--16B90oW2L6FRR3A  39962585446
# 1    HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA  41604896923
# 2  BILLIE EILISH  UCVNE660NcgYzi18LwwUZb7Q     14316364
# 3       Shemaroo  UCF1JIbMUs6uqoZEY1Haw0GQ  27011004224
# 4    JuegaGerman  UCYiGq8XF7YQD00x7wAd62Zg  17573028501
#
#                                             category country defaultLanguage  \
# 0  Music of Asia, Pop music, Music, Electronic music      KR             NaN
# 1     Hip hop music, Pop music, Music, Music of Asia      KR             NaN
# 2                                                NaN     NaN             NaN
# 3                                Entertainment, Film      IN             NaN
# 4  Role-playing video game, Action game, Video ga...      CL             NaN
#
#    subscriber_count          created_date  \
# 0          99000000  2016-06-29T03:15:23Z
# 1          78700000  2008-06-04T08:23:22Z
# 2             82300  2019-01-18T05:14:32Z
# 3          60400000  2007-09-01T11:44:51Z
# 4          54200000  2013-05-19T00:09:13Z
#
#                                          description         custom_url  \
# 0  BLACKPINK Official YouTube Channel 블랙핑크 공식 유튜브...         @blackpink
# 1  Welcome to the official YouTube channel of HYB...        @hybelabels
# 2                                                NaN  @billieeilish8477
# 3  Welcome to ShemarooEnt, one of the finest dest...          @shemaroo
# 4                                 Lento pero seguro.       @juegagerman
#
#                                            thumbnail  video_count  \
# 0  https://yt3.ggpht.com/U3VrCkKjzTpQ3VYv4SCPjNfD...          636
# 1  https://yt3.ggpht.com/ytc/AIdro_l8g0yRFG8xoe_q...         2817
# 2  https://yt3.ggpht.com/ytc/AIdro_n3NfvUAVtcUJvW...            1
# 3  https://yt3.ggpht.com/ytc/AIdro_mhdF4RNZM9OHP-...        13374
# 4  https://yt3.ggpht.com/vOsrLzWD4z1dbr470nEXydi3...         2368
#
#    videos_last_30_days  views_last_30_days       uploads_playlist_id  \
# 0                    1             3256869  UUOmHUn--16B90oW2L6FRR3A
# 1                   79            46074833  UU3IZKseVpdzPSBaWxBxundA
# 2                    0                   0  UUVNE660NcgYzi18LwwUZb7Q
# 3                   63            10560897  UUF1JIbMUs6uqoZEY1Haw0GQ
# 4                   12            22980501  UUYiGq8XF7YQD00x7wAd62Zg
#
#                                    last_10_video_ids
# 0  W-9-keHNwV8,pAeqY-TEZc0,WB_AOdAEuBM,zTnAvaoHR4...
# 1  NPqiynCpqgI,nbOuR-KYZy8,xf8N3JYEhV4,iIWKCYP2zY...
# 2                                        C9odQay_d6s
# 3  KPYx-APpvo4,HscCQYIX4fg,TP64Sacd5Nw,G8a5vnD2A0...
# 4  JjWksJW1Z0M,_NhOyRPXA5s,EYXTxxjU0Ks,5eAyv6b84p...

# %%
cols = ["channel_id", "channel_name", "description", "country", "defaultLanguage", "created_date", "category", "aggregated_tags", "most_common_video_genre", "all_video_genres", "avg_duration_seconds", "avg_seconds_between_uploads", "recent_video_titles"]

# %%
df = df.drop(columns=[c for c in df.columns if c not in cols])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15830 entries, 0 to 15829
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   channel_name     15830 non-null  object
#  1   channel_id       15830 non-null  object
#  2   category         15722 non-null  object
#  3   country          14030 non-null  object
#  4   defaultLanguage  1725 non-null   object
#  5   created_date     15830 non-null  object
#  6   description      14929 non-null  object
# dtypes: object(7)
# memory usage: 865.8+ KB

# %% [markdown]
# index 2 billie eilish is impersonation account...

# %%
df = df.drop(index=2).reset_index(drop=True)

# %%
channels = []
exception_counter = 0

for channel_id in df["channel_id"][:10]:
    print(channel_id)
    try:
        channel_data = main(channel_id)
        channels.append(channel_data)
    except Exception as e:
        exception_counter += 1;
        print(f"Failed for {channel_id}") #TODO: integrate exception handling into entire data extraction flow
# Out:
# UCOmHUn--16B90oW2L6FRR3A
# UC3IZKseVpdzPSBaWxBxundA
# UCF1JIbMUs6uqoZEY1Haw0GQ
# UCYiGq8XF7YQD00x7wAd62Zg
# UC4NALVCmcmL5ntpV0thoH6w
# UCJrDMFOdv1I2k8n9oK_V21w
# duration format doesn't match
# UCX6OQ3DkcsbYNE6H8uQQuVA
# UCK1i2UviaXLUNrZlAFpw_jA
# UCIwFjwMjI0y7PDBVEO9-bkQ
# UCpEhnqL0y41EpW2TvWAHD7Q

# %%
new_df = pd.DataFrame(channels)
print(f"Exception counter:{exception_counter}")
print(f"Improper duration counter:{improper_duration_counter}")
# Out:
# Exception counter:0
# Improper duration counter:0

# %%
new_df.head(10)
# Out:
#                  channel_id  \
# 0  UCOmHUn--16B90oW2L6FRR3A
# 1  UC3IZKseVpdzPSBaWxBxundA
# 2  UCF1JIbMUs6uqoZEY1Haw0GQ
# 3  UCYiGq8XF7YQD00x7wAd62Zg
# 4  UC4NALVCmcmL5ntpV0thoH6w
# 5  UCJrDMFOdv1I2k8n9oK_V21w
# 6  UCX6OQ3DkcsbYNE6H8uQQuVA
# 7  UCK1i2UviaXLUNrZlAFpw_jA
# 8  UCIwFjwMjI0y7PDBVEO9-bkQ
# 9  UCpEhnqL0y41EpW2TvWAHD7Q
#
#                                         channel_name  \
# 0                                          BLACKPINK
# 1                                        HYBE LABELS
# 2                                           Shemaroo
# 3                                        JuegaGerman
# 4  LooLoo Kids - Nursery Rhymes and Children's Songs
# 5                                      Tips Official
# 6                                            MrBeast
# 7                                  El Reino Infantil
# 8                                      Justin Bieber
# 9                                          SET India
#
#                                          description country defaultLanguage  \
# 0  BLACKPINK Official YouTube Channel\n블랙핑크 공식 유튜...      KR            None
# 1  Welcome to the official YouTube channel of HYB...      KR            None
# 2  Welcome to ShemarooEnt, one of the finest dest...      IN            None
# 3                                Lento pero seguro.       CL            None
# 4  LooLoo Kids💖 is an educational YouTube channel...      US              en
# 5  The proud history of Tips Music Limited (Forme...      IN            None
# 6  SUBSCRIBE FOR A COOKIE!\nNew MrBeast or MrBeas...      US              en
# 7  El Reino Infantil es la comunidad digital para...      AR            None
# 8                                                         CA            None
# 9  Sony Entertainment Television is one of the le...      IN            None
#
#            created_date                                           category  \
# 0  2016-06-29T03:15:23Z  [Music, Music of Asia, Pop music, Electronic m...
# 1  2008-06-04T08:23:22Z                  [Music of Asia, Music, Pop music]
# 2  2007-09-01T11:44:51Z                              [Film, Entertainment]
# 3  2013-05-19T00:09:13Z  [Action-adventure game, Video game culture, Ac...
# 4  2014-08-05T20:15:33Z                       [Film, Music, Entertainment]
# 5  2007-05-22T10:13:28Z            [Pop music, Music of Asia, Music, Film]
# 6  2012-02-20T00:43:50Z             [Entertainment, Lifestyle (sociology)]
# 7  2011-06-02T16:20:07Z                       [Film, Music, Entertainment]
# 8  2007-01-15T21:17:27Z  [Music, Pop music, Electronic music, Soul musi...
# 9  2006-09-20T22:24:59Z  [Music of Asia, Entertainment, Television prog...
#
#                                      aggregated_tags most_common_video_genre  \
# 0  [JISOO, YG, JENNIE You & Me, LISA, JENNIE 유앤미,...                   Music
# 1                  [하이브, 하이브레이블즈, HYBE LABELS, HYBE]                   Music
# 2  [salman khan movies, ramcharana moves, Mega Po...           Entertainment
# 3  [revenia, juega german, juego de miedo, click ...                  Gaming
# 4  [kids videos, children songs, farm song nurser...                   Music
# 5  [Itna Main Chahoon Tujhe Koi Kisi Ko Na Chahe,...                   Music
# 6                                                 []           Entertainment
# 7  [mes de la amistad, bebe looloo kids, youtube,...                   Music
# 8  [sorry, purpose, believe, anyone, beauty and a...                   Music
# 9  [cid, new business ideas, business deals, shar...           Entertainment
#
#          all_video_genres  avg_duration_seconds  avg_days_between_uploads  \
# 0                 [Music]                 211.6                     11.33
# 1                 [Music]                  89.6                      1.22
# 2         [Entertainment]                5336.1                      0.00
# 3                [Gaming]                2046.9                      2.78
# 4                 [Music]                 148.5                      1.56
# 5                 [Music]                1435.3                      0.00
# 6         [Entertainment]                 303.8                      3.78
# 7  [Entertainment, Music]                 466.4                      0.78
# 8                 [Music]                 179.1                      3.44
# 9         [Entertainment]                2800.6                      0.00
#
#                                  recent_video_titles
# 0  [BLACKPINK - WORLD TOUR [DEADLINE] IN HONG KON...
# 1  [SANTOS BRAVOS “KAWASAKI (&TEAM Remix)” Lyric ...
# 2  [Mega Power Star Ram Charan 👑 | Zanjeer (4K Ac...
# 3  [Fotos Tomadas En El Momento PERFECTO 📸, Traba...
# 4  [Old Macdonald Had a Farm Song + Johny Johny Y...
# 5  [From enemies to allies, their bond defined a ...
# 6  [Every Step You Take, Win $1,000, Surprising M...
# 7  [Cinco Patitos 🪿 | FAMILIA BLU 💙 Canción Infan...
# 8  [Justin Bieber - BAD HONEY, Justin Bieber - SP...
# 9  [Shark Tank India S5 | Sharks को हुए Heizen की...

# %%
df.head(10)
# Out:
#                                         channel_name  \
# 0                                          BLACKPINK
# 1                                        HYBE LABELS
# 2                                      BILLIE EILISH
# 3                                           Shemaroo
# 4                                        JuegaGerman
# 5  LooLoo Kids - Nursery Rhymes and Children's Songs
# 6                                      Tips Official
# 7                                            MrBeast
# 8                                  El Reino Infantil
# 9                                      Justin Bieber
#
#                  channel_id  \
# 0  UCOmHUn--16B90oW2L6FRR3A
# 1  UC3IZKseVpdzPSBaWxBxundA
# 2  UCVNE660NcgYzi18LwwUZb7Q
# 3  UCF1JIbMUs6uqoZEY1Haw0GQ
# 4  UCYiGq8XF7YQD00x7wAd62Zg
# 5  UC4NALVCmcmL5ntpV0thoH6w
# 6  UCJrDMFOdv1I2k8n9oK_V21w
# 7  UCX6OQ3DkcsbYNE6H8uQQuVA
# 8  UCK1i2UviaXLUNrZlAFpw_jA
# 9  UCIwFjwMjI0y7PDBVEO9-bkQ
#
#                                             category country defaultLanguage  \
# 0  Music of Asia, Pop music, Music, Electronic music      KR             NaN
# 1     Hip hop music, Pop music, Music, Music of Asia      KR             NaN
# 2                                                NaN     NaN             NaN
# 3                                Entertainment, Film      IN             NaN
# 4  Role-playing video game, Action game, Video ga...      CL             NaN
# 5                         Entertainment, Music, Film      US              en
# 6              Film, Music, Music of Asia, Pop music      IN             NaN
# 7         Lifestyle (sociology), Entertainment, Film      US              en
# 8                         Music, Entertainment, Film      AR             NaN
# 9  Hip hop music, Music, Pop music, Electronic mu...      CA             NaN
#
#            created_date                                        description
# 0  2016-06-29T03:15:23Z  BLACKPINK Official YouTube Channel 블랙핑크 공식 유튜브...
# 1  2008-06-04T08:23:22Z  Welcome to the official YouTube channel of HYB...
# 2  2019-01-18T05:14:32Z                                                NaN
# 3  2007-09-01T11:44:51Z  Welcome to ShemarooEnt, one of the finest dest...
# 4  2013-05-19T00:09:13Z                                 Lento pero seguro.
# 5  2014-08-05T20:15:33Z  LooLoo Kids💖 is an educational YouTube channel...
# 6  2007-05-22T10:13:28Z  The proud history of Tips Music Limited (Forme...
# 7  2012-02-20T00:43:50Z  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...
# 8  2011-06-02T16:20:07Z  El Reino Infantil es la comunidad digital para...
# 9  2007-01-15T21:17:27Z                                                NaN

# %% [markdown]
# ## misc

# %%
channel_data = main("UCOmHUn--16B90oW2L6FRR3A")
print(json.dumps(channel_data, indent=2))
# Out:
# {
#   "channel_id": "UCOmHUn--16B90oW2L6FRR3A",
#   "channel_name": "BLACKPINK",
#   "description": "BLACKPINK Official YouTube Channel\n\ube14\ub799\ud551\ud06c \uacf5\uc2dd \uc720\ud29c\ube0c \ucc44\ub110\uc785\ub2c8\ub2e4.\n\nJISOO, JENNIE, ROS\u00c9, LISA\n\uc9c0\uc218, \uc81c\ub2c8, \ub85c\uc81c, \ub9ac\uc0ac",
#   "country": "KR",
#   "defaultLanguage": null,
#   "created_date": "2016-06-29T03:15:23Z",
#   "category": [
#     "Electronic music",
#     "Music",
#     "Music of Asia",
#     "Pop music"
#   ],
#   "aggregated_tags": [
#     "JISOO",
#     "YG",
#     "JENNIE You & Me",
#     "LISA",
#     "JENNIE \uc720\uc564\ubbf8",
#     "\uc640\uc774\uc9c0",
#     "\ube14\ub9c1\ud06c",
#     "\uc720\uc564\ubbf8",
#     "JENNIE COACHELLA",
#     "JENNIE You and ME",
#     "BLINK",
#     "\uc81c\ub2c8 \ucf54\uccbc\ub77c",
#     "JENNIE",
#     "\ube14\ud551",
#     "\ub85c\uc81c",
#     "ROS\u00c9",
#     "\uc9c0\uc218",
#     "\ube14\ub799\ud551\ud06c",
#     "\uc81c\ub2c8 You and Me",
#     "\uc81c\ub2c8 \uc720\uc564\ubbf8",
#     "YG Entertainment",
#     "\uc81c\ub2c8 You & Me",
#     "You and Me",
#     "You & Me",
#     "\ub9ac\uc0ac",
#     "\uc81c\ub2c8",
#     "BLACKPINK",
#     "K-pop"
#   ],
#   "most_common_video_genre": "Music",
#   "all_video_genres": [
#     "Music"
#   ],
#   "avg_duration_seconds": 211.6,
#   "avg_days_between_uploads": 11.33,
#   "recent_video_titles": [
#     "BLACKPINK - WORLD TOUR [DEADLINE] IN HONG KONG Behind the Scenes",
#     "BLACKPINK - WORLD TOUR [DEADLINE] IN TOKYO Behind the Scenes",
#     "BLACKPINK WORLD TOUR [DEADLINE] IN HONG KONG \ud83c\udf86",
#     "BLACKPINK WORLD TOUR [DEADLINE] IN TOKYO \ud83d\uddfc",
#     "BLACKPINK 3rd MINI ALBUM [DEADLINE]",
#     "BLACKPINK 3rd MINI ALBUM [DEADLINE]",
#     "BLACKPINK - WORLD TOUR [DEADLINE] IN BANGKOK Behind the Scenes",
#     "BLACKPINK WORLD TOUR [DEADLINE] IN SINGAPORE \ud83c\udf38 #BLACKPINK #WORLDTOUR #DEADLINE_IN_SINGAPORE",
#     "BLACKPINK WORLD TOUR [DEADLINE] IN BULACAN \ud83d\udc9f #BLACKPINK #WORLDTOUR #DEADLINE #DEADLINE_IN_BULACAN",
#     "BLACKPINK WORLD TOUR [DEADLINE] IN JAKARTA \ud83c\udf34 #BLACKPINK #WORLDTOUR #DEADLINE #DEADLINE_IN_JAKARTA"
#   ]
# }

# %%
df.head()
# Out:
#     channel_name                channel_id  \
# 0      BLACKPINK  UCOmHUn--16B90oW2L6FRR3A
# 1    HYBE LABELS  UC3IZKseVpdzPSBaWxBxundA
# 2  BILLIE EILISH  UCVNE660NcgYzi18LwwUZb7Q
# 3       Shemaroo  UCF1JIbMUs6uqoZEY1Haw0GQ
# 4    JuegaGerman  UCYiGq8XF7YQD00x7wAd62Zg
#
#                                             category country defaultLanguage  \
# 0  Music of Asia, Pop music, Music, Electronic music      KR             NaN
# 1     Hip hop music, Pop music, Music, Music of Asia      KR             NaN
# 2                                                NaN     NaN             NaN
# 3                                Entertainment, Film      IN             NaN
# 4  Role-playing video game, Action game, Video ga...      CL             NaN
#
#            created_date                                        description
# 0  2016-06-29T03:15:23Z  BLACKPINK Official YouTube Channel 블랙핑크 공식 유튜브...
# 1  2008-06-04T08:23:22Z  Welcome to the official YouTube channel of HYB...
# 2  2019-01-18T05:14:32Z                                                NaN
# 3  2007-09-01T11:44:51Z  Welcome to ShemarooEnt, one of the finest dest...
# 4  2013-05-19T00:09:13Z                                 Lento pero seguro.

# %%
df_test = pd.DataFrame([channel_data])
df_test
# Out:
#                  channel_id channel_name  \
# 0  UCOmHUn--16B90oW2L6FRR3A    BLACKPINK
#
#                                          description country defaultLanguage  \
# 0  BLACKPINK Official YouTube Channel\n블랙핑크 공식 유튜...      KR            None
#
#            created_date                                           category  \
# 0  2016-06-29T03:15:23Z  [Electronic music, Pop music, Music of Asia, M...
#
#                                      aggregated_tags most_common_video_genre  \
# 0  [JISOO, YG, JENNIE You & Me, LISA, JENNIE 유앤미,...                   Music
#
#   all_video_genres  avg_duration_seconds  avg_days_between_uploads  \
# 0          [Music]                 211.6                     11.33
#
#                                  recent_video_titles
# 0  [BLACKPINK - WORLD TOUR [DEADLINE] IN HONG KON...

# %%
df["category"][0]
# Out:
# 'Music of Asia, Pop music, Music, Electronic music'

# %%
df_test["category"][0][0]
# Out:
# 'Electronic music'
