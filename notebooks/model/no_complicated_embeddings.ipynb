# %% [markdown]
# ## config

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MultiLabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
import matplotlib.pyplot as plt
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA

import json
import glob

# %%
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
with open ("../performative.txt", "r") as f:
    lines = f.readlines()
    API_KEY = lines[2].strip()
    
yt = build("youtube", "v3", developerKey=API_KEY)

# %% [markdown]
# ## from EDA

# %%
all_data = []
for file in glob.glob("../data/processed/*.json"):
    print(file)
    with open(file, "r") as f:
        all_data.extend(json.load(f))

df = pd.DataFrame(all_data)
df = df.dropna(thresh=8)
df = df.reset_index(drop=True)
# Out:
# ../data/processed\channels0_99.json
# ../data/processed\channels100_.json
# ../data/processed\channels3425_.json
# ../data/processed\channels6727_.json
# ../data/processed\channelsa10034_.json
# ../data/processed\channelsa13313_.json
# ../data/processed\channels_missing.json

# %%
df["created_date"] = pd.to_datetime(df["created_date"], format="ISO8601")

# %%
time_cols = ["created_date"]
num_cols = ["avg_duration_seconds", "avg_seconds_between_uploads"]
basic_cat_cols = ["country", "most_common_video_genre"]
multi_cat_cols = ["category", "all_video_genres"]
text_cols = ["description", "aggregated_tags", "recent_video_titles"]
drop_cols = ["channel_id", "channel_name", "defaultLanguage"]
set(time_cols + num_cols + basic_cat_cols + multi_cat_cols + text_cols + drop_cols) == set(df.columns)
# Out:
# True

# %% [markdown]
# TODO: investigate below scaling step

# %%
df["avg_seconds_between_uploads"] = df["avg_seconds_between_uploads"].fillna(df["avg_seconds_between_uploads"].max())

# %%
class DateTimeToPosix(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        return (pd.to_datetime(X.iloc[:, 0]).astype(int) // 10**9).values.reshape(-1, 1)
    def get_feature_names_out(self, input_features=None):
        return ["created_date_posix"]

# %%
# MLB does not have fit/transform. must wrap in custom transformer, give it fit/transform, and col transformer will accept
class MultiLabelBinarizerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.mlb = MultiLabelBinarizer()
    
    def fit(self, X, y=None):
        self.mlb.fit(X.iloc[:, 0])
        return self
    
    def transform(self, X, y=None):
        return self.mlb.transform(X.iloc[:, 0])
    
    def get_feature_names_out(self, input_features=None):
        return self.mlb.classes_

# %% [markdown]
# ## text embeddings experimentation

# %% [markdown]
# ### nltk/spacy playing

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import spacy

# %%
nlp = spacy.load("en_core_web_md")
doc = nlp("pineapple") 
doc.vector[:10]
# Out:
# array([-0.63358,  0.12266,  0.47232, -0.22974, -0.26307,  0.56499,
#        -0.72338,  0.16736,  0.4203 ,  0.93788], dtype=float32)

# %%
text = (
    "UBC is one of the well known universities in British Columbia. "
    "UBC CS teaching team is truly multicultural!! "
    "Dr. Toti completed her Ph.D. in Italy."
    "Dr. Moosvi, Dr. Kolhatkar, and Dr. Ola completed theirs in Canada."
    "Dr. Heeren and Dr. Lécuyer completed theirs in the U.S."
)
print(text.split("."))

sent_tokenized = sent_tokenize(text)
print(sent_tokenized)
# Out:
# ['UBC is one of the well known universities in British Columbia', ' UBC CS teaching team is truly multicultural!! Dr', ' Toti completed her Ph', 'D', ' in Italy', 'Dr', ' Moosvi, Dr', ' Kolhatkar, and Dr', ' Ola completed theirs in Canada', 'Dr', ' Heeren and Dr', ' Lécuyer completed theirs in the U', 'S', '']
# ['UBC is one of the well known universities in British Columbia.', 'UBC CS teaching team is truly multicultural!!', 'Dr. Toti completed her Ph.D. in Italy.Dr.', 'Moosvi, Dr. Kolhatkar, and Dr. Ola completed theirs in Canada.Dr.', 'Heeren and Dr. Lécuyer completed theirs in the U.S.']

# %%
print("Splitting on whitespace: ", [sent.split() for sent in sent_tokenized])
print("Splitting on whitespace: ", [word_tokenize(sent) for sent in sent_tokenized])
# Out:
# Splitting on whitespace:  [['UBC', 'is', 'one', 'of', 'the', 'well', 'known', 'universities', 'in', 'British', 'Columbia.'], ['UBC', 'CS', 'teaching', 'team', 'is', 'truly', 'multicultural!!'], ['Dr.', 'Toti', 'completed', 'her', 'Ph.D.', 'in', 'Italy.Dr.'], ['Moosvi,', 'Dr.', 'Kolhatkar,', 'and', 'Dr.', 'Ola', 'completed', 'theirs', 'in', 'Canada.Dr.'], ['Heeren', 'and', 'Dr.', 'Lécuyer', 'completed', 'theirs', 'in', 'the', 'U.S.']]
# Splitting on whitespace:  [['UBC', 'is', 'one', 'of', 'the', 'well', 'known', 'universities', 'in', 'British', 'Columbia', '.'], ['UBC', 'CS', 'teaching', 'team', 'is', 'truly', 'multicultural', '!', '!'], ['Dr.', 'Toti', 'completed', 'her', 'Ph.D.', 'in', 'Italy.Dr', '.'], ['Moosvi', ',', 'Dr.', 'Kolhatkar', ',', 'and', 'Dr.', 'Ola', 'completed', 'theirs', 'in', 'Canada.Dr', '.'], ['Heeren', 'and', 'Dr.', 'Lécuyer', 'completed', 'theirs', 'in', 'the', 'U.S', '.']]

# %% [markdown]
# ### embedding/dataset pruning

# %% [markdown]
# #### list -> free text

# %%
df["aggregated_tags"] = df["aggregated_tags"].apply(lambda x: " ".join(x) if isinstance(x, list) else x)
df["recent_video_titles"] = df["recent_video_titles"].apply(lambda x: " ".join(x) if isinstance(x, list) else x)

# %%
df.head()
# Out:
#                  channel_id  \
# 0  UCOmHUn--16B90oW2L6FRR3A
# 1  UC3IZKseVpdzPSBaWxBxundA
# 2  UCF1JIbMUs6uqoZEY1Haw0GQ
# 3  UCYiGq8XF7YQD00x7wAd62Zg
# 4  UC4NALVCmcmL5ntpV0thoH6w
#
#                                         channel_name  \
# 0                                          BLACKPINK
# 1                                        HYBE LABELS
# 2                                           Shemaroo
# 3                                        JuegaGerman
# 4  LooLoo Kids - Nursery Rhymes and Children's Songs
#
#                                          description country defaultLanguage  \
# 0  BLACKPINK Official YouTube Channel\n블랙핑크 공식 유튜...      KR            None
# 1  Welcome to the official YouTube channel of HYB...      KR            None
# 2  Welcome to ShemarooEnt, one of the finest dest...      IN            None
# 3                                Lento pero seguro.       CL            None
# 4  LooLoo Kids💖 is an educational YouTube channel...      US              en
#
#                created_date  \
# 0 2016-06-29 03:15:23+00:00
# 1 2008-06-04 08:23:22+00:00
# 2 2007-09-01 11:44:51+00:00
# 3 2013-05-19 00:09:13+00:00
# 4 2014-08-05 20:15:33+00:00
#
#                                             category  \
# 0  [Electronic music, Pop music, Music of Asia, M...
# 1                  [Pop music, Music, Music of Asia]
# 2                              [Film, Entertainment]
# 3  [Action game, Video game culture, Action-adven...
# 4                       [Entertainment, Music, Film]
#
#                                      aggregated_tags most_common_video_genre  \
# 0  JISOO YG JENNIE You & Me LISA JENNIE 유앤미 와이지 블...                   Music
# 1                       하이브 하이브레이블즈 HYBE LABELS HYBE                   Music
# 2  salman khan movies ramcharana moves Mega Power...           Entertainment
# 3  revenia juega german juego de miedo click to c...                  Gaming
# 4  kids videos children songs farm song nursery r...                   Music
#
#   all_video_genres  avg_duration_seconds  avg_seconds_between_uploads  \
# 0          [Music]              211.6000                 1017992.8900
# 1          [Music]               89.6000                  131588.1100
# 2  [Entertainment]             5336.1000                   45200.0000
# 3         [Gaming]             2046.9000                  280466.0000
# 4          [Music]              148.5000                  181623.8900
#
#                                  recent_video_titles
# 0  BLACKPINK - WORLD TOUR [DEADLINE] IN HONG KONG...
# 1  SANTOS BRAVOS “KAWASAKI (&TEAM Remix)” Lyric V...
# 2  Mega Power Star Ram Charan 👑 | Zanjeer (4K Act...
# 3  Fotos Tomadas En El Momento PERFECTO 📸 Trabajo...
# 4  Old Macdonald Had a Farm Song + Johny Johny Ye...

# %%
df["country"].value_counts()
# Out:
# country
# US    4930
# IN    2307
# GB    1667
# CA    1160
# AU     958
#       ...
# LA       1
# OM       1
# HN       1
# ME       1
# UM       1
# Name: count, Length: 109, dtype: int64

# %%
english_speaking = ['US', 'GB', 'CA', 'AU', 'IE', 'NZ', 'SG', 'ZA', 'NG', 'GH', 'JM', 'VI', 'BM', 'AG']

# %%
df_english_country = df[df["country"].isin(english_speaking)]

# %%
def is_english(text):
    if not isinstance(text, str):
        return True
    # Allow ASCII + common special chars + emojis
    return bool(re.match(r'^[\x00-\x7F\u00C0-\u024F\u2000-\u206F\u2100-\u214F\u2190-\u21FF\u2600-\u27BF\U0001F300-\U0001FAFF©®™—…•""'']*$', text))

# %%
mask = (
    df["description"].apply(is_english) &
    df["aggregated_tags"].apply(is_english) &
    df["recent_video_titles"].apply(is_english) 
)

df_english_regex  = df[mask]

# %%
print(f"rows after eliminating by country: {len(df_english_country)}")
print(f"rows after  eliminating by regex: {len(df_english_regex)}")
# Out:
# rows after eliminating by country: 8861
# rows after  eliminating by regex: 9759

# %%
df_english_regex.head()
# Out:
#                   channel_id      channel_name  \
# 6   UCX6OQ3DkcsbYNE6H8uQQuVA           MrBeast
# 8   UCIwFjwMjI0y7PDBVEO9-bkQ     Justin Bieber
# 12  UC56gTxNs4f9xZ7Pa2i5xNzg  Sony Music India
# 13  UC0C-w0YjGpqDXGB8IHb662A        Ed Sheeran
# 16  UC9CoOnJkIBMdeijd9qYoT_g     Ariana Grande
#
#                                           description country defaultLanguage  \
# 6   SUBSCRIBE FOR A COOKIE!\nNew MrBeast or MrBeas...      US              en
# 8                                                          CA            None
# 12  Welcome to Sony Music India's official YouTube...      IN            None
# 13                   Ed Sheeran x\n\nPlay - Out Now\n    None            None
# 16              eternal sunshine deluxe ♡ 📦 out now\n    None            None
#
#                 created_date  \
# 6  2012-02-20 00:43:50+00:00
# 8  2007-01-15 21:17:27+00:00
# 12 2009-09-02 23:16:22+00:00
# 13 2006-08-08 13:59:50+00:00
# 16 2007-01-22 01:53:12+00:00
#
#                                              category  \
# 6              [Entertainment, Lifestyle (sociology)]
# 8   [Soul music, Music, Pop music, Electronic musi...
# 12  [Soul music, Pop music, Music, Music of Asia, ...
# 13                                 [Pop music, Music]
# 16               [Music, Pop music, Electronic music]
#
#                                       aggregated_tags most_common_video_genre  \
# 6                                                               Entertainment
# 8   sorry purpose believe anyone beauty and a beat...                   Music
# 12  panghat song best of ajay atul marathi songs j...                   Music
# 13  ed sheeran live performance perth ed sheeran t...                   Music
# 16  ariana grande brighter days ahead behind the s...                   Music
#
#    all_video_genres  avg_duration_seconds  avg_seconds_between_uploads  \
# 6   [Entertainment]              303.8000                  384399.7800
# 8           [Music]              179.1000                  307323.2200
# 12          [Music]              298.1000                   19199.3300
# 13          [Music]               55.8000                  554464.7800
# 16          [Music]              233.5000                 1427546.2200
#
#                                   recent_video_titles
# 6   Every Step You Take, Win $1,000 Surprising My ...
# 8   Justin Bieber - BAD HONEY Justin Bieber - SPEE...
# 12  Roohi - Audio Jukebox | Nadiyon Paar, Panghat ...
# 13  There’s a new mayor in town Playing a throwbac...
# 16  Ariana Grande - dandelion Ariana Grande - eter...

# %%
text_cols
# Out:
# ['description', 'aggregated_tags', 'recent_video_titles']

# %% [markdown]
# ### putting it together

# %%
ct = make_column_transformer(
    (make_pipeline(DateTimeToPosix(), StandardScaler()), time_cols),
    (StandardScaler(), num_cols),
    (make_pipeline(SimpleImputer(strategy="most_frequent"), OneHotEncoder(handle_unknown="ignore")), basic_cat_cols), #TODO: almost certainly a better way to impute countries
    (MultiLabelBinarizerTransformer(), ["category"]),
    (MultiLabelBinarizerTransformer(), ["all_video_genres"]),
    (CountVectorizer(stop_words="english", max_features=500), "description"), #TODO: figure out best hyperparameters
    (CountVectorizer(stop_words="english", max_features=500), "aggregated_tags"),
    (CountVectorizer(stop_words="english", max_features=500), "recent_video_titles"),
    ("drop", drop_cols)
)

# %% [markdown]
# if no max features actual shape is (7319, 163596), cant visualize

# %%
df_train, df_test = train_test_split(df_english_regex,test_size= 0.01, random_state=67)

# %%
df_train_pp = ct.fit_transform(df_train)
df_test_pp = ct.transform(df_test)

# %%
#TODO: pca, other ways to weight? one hot encoding screws up neighbours maybe?

# %%
pca = PCA()
pca.fit(df_train_pp)
cumvar = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumvar)
plt.axhline(0.95, color='r', linestyle='--', label='95%')
plt.xlabel("n_components")
plt.ylabel("cumulative explained variance")
plt.legend()
plt.show()

# find the elbow
n = np.argmax(cumvar >= 0.95) + 1
print(f"components needed for 95% variance: {n}")
# Out:
# components needed for 95% variance: 648

# %%
pca_real = PCA(n_components=308)
df_train_pca = pca_real.fit_transform(df_train_pp)

# %%
nn = NearestNeighbors(n_neighbors=10, metric="cosine")
nn.fit(df_train_pca)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=10)

# %%
def get_channel_recs_pca(ch):
    distances, indices = nn.kneighbors(ch)

    recs = df.iloc[indices[0]][["channel_name", "channel_id"]]
    recs["distance"] = distances[0]
    return recs

# %% [markdown]
# ### TODO: df.iloc??

# %%
distances, indices = nn.kneighbors()
for i in range(11):  
    print(df_test.iloc[i]["channel_name"])
    recs = df.iloc[indices[i]][["channel_name", "channel_id"]]
    recs["distance"] = distances[i]
    print(recs)
# Out:
# Doctor D.S.
#                  channel_name                channel_id  distance
# 4163            Geography Now  UCmmPgObSUPw1HL2lq6H4ffA    0.7987
# 7180                  Mustard  UC1ZBQ-F-yktYD4m5AzM6pww    0.8225
# 3461                  Relax24  UCBK-IXazHYcYit0K3ESnaxg    0.8245
# 7042        McDonaldsMalaysia  UCOPPIX8eyvkpcA0v_pSNxTg    0.8283
# 5082            New Scientist  UCt5OA3LingpZBeEyPYmputQ    0.8402
# 6144                Trap king  UCTeo335PyMAuePx7FMlPI_w    0.8508
# 934                 TBNRFrags  UCNAz5Ut1Swwg6h6ysBtWFog    0.8634
# 2799          Insider Science  UC9uD-W5zQHQuAVT2GdcLCvg    0.8700
# 5991  Logan The Adventure Dog  UCZK15gahSA5pLV6dakwyPxA    0.8758
# 4155              MiniforceTV  UCmElsfgN0WY4ycwKHKWbTyg    0.8792
# Crunchyroll
#                   channel_name                channel_id  distance
# 8060  Universal Orlando Resort  UCGl3kbSLHfKb3QeOYG7pAuA    0.3142
# 9187                      AARP  UCmyGH1tjNBs2VFtVSAtmNOg    0.3461
# 4366                      Oyff  UCD1QymTi9ei-LPz61a2dPQA    0.3686
# 2243            RC LIVE ACTION  UCT4l7A9S4ziruX6Y8cVQRMw    0.8041
# 2529                 AlotVines  UCJzXOglovnHQAdrJtqwnPZg    0.8125
# 1807                    Ben 10  UCoWgc1mqe-bcfb_lem7EyOg    0.8299
# 3677    The Art of Photography  UC7T8roVtC_3afWKTOGtLlBA    0.8299
# 6137             Lucas T. Jahn  UCG10CJ-y-08b0DPQ1YQ345Q    0.8407
# 987       japanesestuffchannel  UCTzy4FQNreZnkPG7ZlkTA0g    0.8553
# 7365        Voice Chat Podcast  UC-rXxeb-k6k3400m16_Hsqg    0.8593
# edcunhaph
#               channel_name                channel_id  distance
# 966           LadyGagaVEVO  UC07Kxew-cMIaykMOkzqHtBQ    0.7624
# 383              MY FAMILY  UC4B6dDVB0Umrh5l4UgxUtyg    0.7659
# 4761                 HDCYT  UCfHZCZHykS3IQDPyFfnqjWg    0.7783
# 4384           Josh Cahill  UCJmkopWuQxI9U0NQaOcl68Q    0.8004
# 8006     Adult Swim Europe  UCHcMtE3EiKmqrJZBZyUBuRQ    0.8103
# 8000        ABS-CBN Sports  UCzrdtk6p4SaakMz2ZmOkCQQ    0.8120
# 1552                 Petco  UCHlPhu5O4_ji4UYOG2RB-YQ    0.8122
# 8869              Zoe Sugg  UCrUbqTCagwsaP2Fmr0p1TsA    0.8140
# 4856  DRJ Records Classics  UC91ZmVoOSEPCeogJTQR0Fig    0.8196
# 8681              PTC NEWS  UCQLEbraENUGWh6p1Rv664rQ    0.8210
# SciManDan
#                      channel_name                channel_id  distance
# 4194  Editorial Natural Beauty556  UCbqVxtjS0NVRcfBH27_GtEA    0.6552
# 5091                   Hub Cinema  UCuwQyaVxILdpsVgUJg1NYww    0.6775
# 244                     LIV Crime  UCzXpAx4v6rFLYXkJZ5nmSvQ    0.6895
# 4822                      Araathi  UCCMUnWvJyTEUunnygpTGfow    0.6965
# 361          Doggy Doggy Cartoons  UC_W0_Nv-3rxpWVvosddhrPw    0.6977
# 474          Hacksmith Industries  UCjgpFI5dU-D1-kh9H1muoxQ    0.6982
# 4645                      LEMMiNO  UCRcgy6GzDeccI7dkbbBna3Q    0.7028
# 5050     Shaun the Sheep Official  UCS7H8U-n5mINVJjJsaRtGHg    0.7033
# 4220                    HandCraft  UCEyr6FYPqXj3agOBSBPyLWw    0.7053
# 8721                   ZoëTwoDots  UC-10uJUkzxSXa9sEtV67YcA    0.7053
# Yung Filly
#               channel_name                channel_id  distance
# 3049     Eetzi Productions  UCbMFCrRXddNEIhbqmmxoxeg    0.5859
# 1456  Entertainment Access  UCA0MDADBWmCFro3SXR5mlSg    0.5957
# 2926       Live From Earth  UCYlA760v0OsEWqPZKvT98aA    0.6437
# 8621            MightyToys  UCuW8NszZfAwPm5_qPJ1m9Hg    0.6585
# 6559  Noel Miller Presents  UCukxwCc4hhZrMtlLVEY_Dxw    0.6711
# 37         JioHotstar Kids  UCJg19noZp7-BYIGvypu_cow    0.6963
# 843                 Chetak  UCQEloCMWEZFep85nHfbbg8Q    0.7013
# 4435       CatPusic Shorts  UCtSkU7XyWmwN5YvUrHDH9jg    0.7064
# 7815      OFF PLANET FILMS  UCvnZnDrsW9VG8kjGcI07ktA    0.7083
# 8252      Car News Central  UCE1rh8YHogAaKFRaUawqL9A    0.7174
# WAY AWAY
#              channel_name                channel_id  distance
# 3456      Hugo Cornellier  UCiEBv40OQ7zB68aK3lltQMg    0.5915
# 5883        Jules LeBlanc  UCuQ9PbS08dQJNWfwjQE-Fnw    0.7060
# 2849  Post Malone - Topic  UCyD3XWRK9ko-izf2nBSFitw    0.7471
# 5158          Holly Dolke  UCK5PP5Up6Dz80dv5G4XuiiA    0.7569
# 8188            SEAN LONG  UCV-bDec0e7fbZLOvlBNYTow    0.7722
# 7858          Mafia Jovem  UC5eBQNA-OQqp2MlzEoBjwYw    0.7805
# 2987      Anton somewhere  UCk0LtHycs4deT5bkRqrPw2A    0.7955
# 8193           E BULL JET  UChI93tTLaYMNvdLii9uhXtg    0.8049
# 3469      Satisfied Crush  UCCjrlfZHkMo89LwGlVIXL8A    0.8054
# 3877   GlobeTrotter Alpha  UCM7rCxp0Hp3qktZKeEtKqcg    0.8113
# Infamous Swoosh
#            channel_name                channel_id  distance
# 3118     KING WORLDWIDE  UC5zgmSfxcmZRFKqYF32Tr_Q    0.7778
# 1712               Poke  UC8qNcrcCOpYIsWWwkX9mDGQ    0.7993
# 4471   Georgia Aquarium  UCCHvyiHdlh78vwUTHMw6NFQ    0.8072
# 7858        Mafia Jovem  UC5eBQNA-OQqp2MlzEoBjwYw    0.8115
# 1432              Fanta  UCMcJfwaSdyMMn1u6BnoaKEw    0.8158
# 4835  Colleen Ballinger  UCR-QYzXrZF8yFarK8wZbHog    0.8257
# 1137     Carla Morrison  UC4XDU9cYyVAkB5Uk7bHpEPw    0.8436
# 6309      Namoh Studios  UC8UlgEBOrpXouSadI9tAw3Q    0.8611
# 2865          BdotAdot5  UCrrgwgOKqOWlvQaxC58fAbg    0.8638
# 7899              小乌副频道  UCQvvVtUqtGxqSLixdeG75Uw    0.8640
# MATTY MATHESON
#               channel_name                channel_id  distance
# 4608                   EXO  UCzCedBCSSltI1TFd3bKyN6g    0.3955
# 9059         Tommo Carroll  UCyi06SeKkiwoAzFVmQtDtfg    0.4147
# 1324          SuperbLyrics  UCy9zjfGD_LGnfaz27K5pvnw    0.4218
# 5949     NardwuarServiette  UC8h8NJG9gacZ5lAJJvhD0fQ    0.4575
# 2743  Steve Morris Engines  UCYI0jaSzd7aLRj7KCGHkz3g    0.4972
# 8953                  Relm  UCX0Li3JxkKVPIHAamYe-YmQ    0.5566
# 971       KanhaiyaCassette  UChjSqyxh6Y0IyKXw4Ta2AfQ    0.6414
# 4160        Vertex Records  UC_IVhAlM2q2tFtCXP3R0ncw    0.6617
# 5073            City Girls  UCMKv9a5OeqElzuWy1WOR0kA    0.6762
# 7246   Kch Multimedia Naat  UCYIZJ8RJhV6JM32l0XVXM-g    0.7486
# FortNine
#           channel_name                channel_id  distance
# 5364      MrSweetCraft  UCoJrJ_VPPgyDr2TymgRRptw    0.9005
# 2847       Matt Kempke  UCfV8O1xhlB8O9YGz9ywmn8A    0.9056
# 4836    Gnarly Charlie  UCWFPOpUyJSPt2zz-p-LDXkQ    0.9089
# 1998   SahibNoor Singh  UCyQ_pkccmIIE6pEAWIC7dcw    0.9128
# 801        YuridiaVEVO  UC22QP-rNb5wWyJ0BQOWlXQA    0.9162
# 2661     Everyday Food  UCl0kP-Cfe-GGic7Ilnk-u_Q    0.9172
# 67    Luisito Comunica  UCECJDeK0MNapZbpaOzxrUPA    0.9186
# 7613             shane  UCV9_KinVpV-snHe3C3n1hvA    0.9231
# 5390      Rfm VS Games  UC_ZUB-L_cEFjbuttEcpZVKQ    0.9255
# 1297       ZaiLetsPlay  UCPv8L4_1F7FjkmfBqTLXd6w    0.9270
# PopCross Studios
#                                           channel_name  \
# 7234                                             Blarg
# 5084                            CLASSIC COMEDY CHANNEL
# 3004                                       The One Shu
# 4550                                      Pocket Films
# 2039                                     Sunny Bunnies
# 2629                                             Fresh
# 9213                                       BeckBroJack
# 2949  Genevieve's Playhouse - Learning Videos for Kids
# 325                                       Busy Fun Ltd
# 7310                                      HERO Toniket
#
#                     channel_id  distance
# 7234  UCorikuuyFz1dZLo3N9nHc4w    0.4600
# 5084  UCwUlit_Tlx3HsgfDX_ladJg    0.4837
# 3004  UC9PfekKMDzLt_tkragAeACw    0.5145
# 4550  UCWnTC8o8AycL6a2eRrKSdBg    0.5423
# 2039  UCHyeWVPbdJNWNxdlsKl3IYA    0.5568
# 2629  UCqsBym4OHrzSp0Nq1eZoMIA    0.5618
# 9213  UC_cvTMeip9po2hZdF3aBXrA    0.5635
# 2949  UCK5Q72Uyo73uRPk8PmM2A3w    0.5658
# 325   UCkKDpnzIG29MA--Sh6oOtWg    0.5796
# 7310  UCeEl6ounfAex3hHMSUdBk_Q    0.5836
# Wisecrack
#            channel_name                channel_id  distance
# 9478        SankeyMagic  UC2X0s6-0luc_Egd01fZX2Tw    0.4706
# 4868      Summer Mckeen  UCiM8OI8ySYAoealLy-YRCbg    0.4796
# 916           Disney FR  UCakQLdwrxuo0KhJ49Sq2csA    0.4979
# 1782   DJHAMIDAOFFICIEL  UC3bmcYcRQ3D4zrHVyzyqjjQ    0.5426
# 9508            HeyDavi  UCOPi8iWwV6BkL-boz69eJ5g    0.5639
# 4942       Grouse House  UCNuaFLcbAeycQAIAW5s7T0Q    0.6096
# 5382             Devoun  UCalHWE_nqBsJL3iaWTe3F8Q    0.6137
# 3872   Rambaan Aushadhi  UCtryOnU88-eeHGNmqNgWcdA    0.6183
# 4567       Top 10 Tamil  UCcep2qK6JmtCmIhgpnrEDJQ    0.6238
# 5350  Sur Action Movies  UC0ymOwjW6A3Q_RQZ4Sr7RNA    0.6371

# %% [markdown]
# next steps: investigate and iterate.
# - do some more predictions
# - intepretability (actual numbers/values for a few rows)
# - dimensionality issues (ohe, text) + PCA
# - compare with predictions from previous model
# - other versions of NearestNeighbours away from scikit learn?
# - visualization library for this nearest neighbours?|
# - focus on a smaller subset of cols and try build up from there if predictions do not improve
# then
# - then get focused dataset once improved

# %% [markdown]
# #### not figured out yet

# %%
def get_channel_recs(ch):
    distances, indices = nn.kneighbors(ch)

    recs = df.iloc[indices[0]][["channel_name", "channel_id"]]
    recs["distance"] = distances[0]
    return recs

# %%
for i in range(11):
    new_channel = df_test_pp.iloc[[i]]
    print(f"{i} {new_channel["channel_name"]}")

    print(get_channel_recs(new_channel))
    print("=============================")
    print("=============================")
    print("=============================")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 2
#       1 for i in range(11):
# ----> 2     new_channel = df_test_pp.iloc[[i]]
#       3     print(f"{i} {new_channel["channel_name"]}")
#       5     print(get_channel_recs(new_channel))
#
# AttributeError: 'csr_matrix' object has no attribute 'iloc'
